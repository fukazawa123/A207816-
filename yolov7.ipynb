# %% [markdown]
# <a href="https://colab.research.google.com/github/fukazawa123/A207816-/blob/main/yolov7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 描画に使う
import matplotlib.pyplot as plt
# %matplotlib inline

# zipファイルを取り扱う
import zipfile

# 画像を読み込む
from PIL import Image

# アップロードに使う
from google.colab import files

# %%
# %cd /content/drive/MyDrive/A2078169
# Out:
# /content/drive/MyDrive/A2078169

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16057, done.
# remote: Total 16057 (delta 0), reused 0 (delta 0), pack-reused 16057
# Receiving objects: 100% (16057/16057), 14.60 MiB | 13.27 MiB/s, done.
# Resolving deltas: 100% (11032/11032), done.

# %%
# 設定ファイルrequirements.txtに従ってパッケージが一括でインストールされる。
# %cd /content/drive/MyDrive/A2078169/yolov5
# !pip install -r requirements.txt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-6711109b4d1c>", line 2, in <cell line: 2>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/A2078169/yolov5')
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
# ...

# %%
# %cd /content/drive/MyDrive/A2078169
# Out:
# /content/drive/MyDrive/A2078169

# %%
# 学習
# !python train.py --img 640 --batch 16 --epochs 200 --data tayolo5/tayolo.yaml --weights yolov5/yolov5s.pt
# Out:
# 2023-12-04 14:11:13.624464: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 14:11:13.624527: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 14:11:13.624567: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd /content/drive/MyDrive/A2078169/yolov5/
# !python detect.py --source data/images/sr1half.mp4 --weights runs/train/exp11//weights/best.pt --conf 0.5 --name sr1half --exist-ok --save-conf --save-txt

# %%
# %cd /content/drive/MyDrive/A2078169/yolov5/
# !python detect.py --source data/images/sr1-00-3-1.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-00-3-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-00-3-1.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-00-3-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-00-4-2.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-00-4-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-00-4-2.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-00-4-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-01-2-1.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-00-2-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-01-2-1.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-00-2-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-01-3-2.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-00-3-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-01-3-2.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-00-3-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-11-7-2.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-11-7-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-11-7-2.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-11-7-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-11-8-1.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-11-8-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-11-8-1.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-11-8-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-12-6-1.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-12-6-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-12-6-1.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-12-6-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-12-7-2.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-12-7-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-12-7-2.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-12-7-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-13-5-2.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-13-5-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-13-5-2.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-13-5-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-13-6-1.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-13-6-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-13-6-1.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-13-6-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-23-6-1.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-23-6-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-23-6-1.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-23-6-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images/sr1-23-7-2.mp4 --weights yolov5s.pt --conf 0.3 --name  sr1-23-7-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/images/sr1-23-7-2.mp4 --weights runs/train/exp11/weights/best.pt --conf 0.2 --name sr1-23-7-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/images
--exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr6-37-18-0.mp4 --weights yolov5s.pt --conf 0.3 --name hr6-37-18-0k --exist-ok --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp13/weights/best.pt'], source=data/video/hr6-37-1-0.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=hr6-37-1-0b, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/104) /content/drive/MyDrive/A2078169/yolov5/data/video/hr6-37-1-0.mp4: 384x640 (no detections), 49.2ms
# video 1/1 (2/104) /content/drive/MyDrive/A2078169/yolov5/data/video/hr6-37-1-0.mp4: 384x640 (no detections), 7.5ms
# ...

# %%
# !python detect.py --source data/video/hr1-44-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-44-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-44-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-44-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-44-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-44-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-44-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-44-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-54-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-54-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-54-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-54-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-54-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-54-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-54-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-54-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-64-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-64-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-64-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-64-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-64-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-64-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-64-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-64-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-67-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-77-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-67-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-77-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-67-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-77-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-67-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-77-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-77-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-78-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-77-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-78-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-77-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-78-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-77-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-78-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-78-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-88-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-78-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-88-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-78-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-88-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-78-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-88-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-88-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-98-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-88-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-98-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-88-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-98-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-88-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-98-00-2k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-98-00-1.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-99-00-1b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-98-00-1.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-99-00-1k --exist-ok --save-txt --save-conf
# !python detect.py --source data/video/hr1-98-00-2.mp4 --weights runs/train/exp13/weights/best.pt --conf 0.2 --name hr1-99-00-2b --exist-ok --save-conf --save-txt
# !python detect.py --source data/video/hr1-98-00-2.mp4 --weights yolov5s.pt --conf 0.3 --name hr1-99-00-2k --exist-ok --save-txt --save-conf
# Out:
# detect: weights=['runs/train/exp13/weights/best.pt'], source=data/video/hr1-44-00-1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=hr1-44-00-1b, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/78) /content/drive/MyDrive/A2078169/yolov5/data/video/hr1-44-00-1.mp4: 384x640 (no detections), 51.5ms
# video 1/1 (2/78) /content/drive/MyDrive/A2078169/yolov5/data/video/hr1-44-00-1.mp4: 384x640 (no detections), 7.5ms
# ...
